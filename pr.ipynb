# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from utils import create_sheets, get_dfs

dataset_name = 'pr'
os.makedirs(dataset_name, exist_ok=True)
dfs = get_dfs()
path = '/media/xandao/d3b6c029-9e4c-4225-a0df-da4f12bf464c/pr'
create_sheets(dfs, path)

# %%
for k, v in dfs.items():
    v.sort_index(inplace=True)
    display(k, v)
    v.to_csv(os.path.join(dataset_name, '%s.csv') % k, sep=';', float_format=',', quoting=2, na_rep=0)
# Out:
# '5+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512  SVC+256 SVC+400  \
# mobilenetv2+mean+1280               NaN               NaN      NaN     NaN
# mobilenetv2+std+1280                NaN               NaN      NaN     NaN
# resnet50v2+mean+2048                NaN               NaN  0.32096     NaN
# resnet50v2+std+2048                 NaN               NaN  0.02667     NaN
# vgg16+mean+512                      NaN          0.482216      NaN     NaN
# vgg16+std+512                       NaN          0.012958      NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '10+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN          0.551396     NaN     NaN
# vgg16+std+512                       NaN          0.012293     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '20+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                          0.303618               NaN
# vgg16+std+512                            0.03748               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN          0.627909     NaN     NaN
# vgg16+std+512                       NaN          0.029674     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                               NaN                   0.363681
# vgg16+std+512                                NaN                   0.011786
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                        0.392511
# vgg16+std+512                         0.019514
# '5+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '10+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '20+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
