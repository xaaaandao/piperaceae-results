# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from utils import create_sheets, get_dfs

dataset_name = 'pr'
os.makedirs(dataset_name, exist_ok=True)
dfs = get_dfs()
path = '/media/xandao/d3b6c029-9e4c-4225-a0df-da4f12bf464c/pr'
create_sheets(dfs, path)

# %%
for k, v in dfs.items():
    v.sort_index(inplace=True)
    display(k, v)
    v.to_csv(os.path.join(dataset_name, '%s.csv') % k, sep=';', float_format=',', quoting=2, na_rep=0)
# Out:
# '5+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                   0.128086                   0.132034
# mobilenetv2+std+1280                    0.021684                   0.018546
# resnet50v2+mean+2048                    0.159419                   0.161298
# resnet50v2+std+2048                     0.003044                   0.013308
# vgg16+mean+512                           0.15898                   0.200242
# vgg16+std+512                           0.010358                   0.019133
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                    0.19578          0.370718
# mobilenetv2+std+1280                    0.014264          0.014009
# resnet50v2+mean+2048                    0.159912               NaN
# resnet50v2+std+2048                     0.019301               NaN
# vgg16+mean+512                          0.222315               NaN
# vgg16+std+512                           0.011436               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280          0.450105               NaN   0.32289   0.39863
# mobilenetv2+std+1280           0.026743               NaN  0.012233  0.024451
# resnet50v2+mean+2048                NaN               NaN   0.32096  0.393043
# resnet50v2+std+2048                 NaN               NaN   0.02667  0.011507
# vgg16+mean+512                      NaN          0.482216  0.320357  0.416153
# vgg16+std+512                       NaN          0.012958  0.010874  0.010308
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280  0.420668                   0.207495
# mobilenetv2+std+1280   0.010311                   0.007388
# resnet50v2+mean+2048   0.450506                   0.206084
# resnet50v2+std+2048    0.017409                   0.009699
# vgg16+mean+512         0.442085                   0.212936
# vgg16+std+512          0.006924                   0.010516
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                   0.219675                   0.238461
# mobilenetv2+std+1280                    0.006811                   0.007215
# resnet50v2+mean+2048                    0.216636                   0.236833
# resnet50v2+std+2048                     0.006998                    0.01496
# vgg16+mean+512                          0.234271                   0.250485
# vgg16+std+512                           0.012284                   0.007202
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.241234                 0.297627
# mobilenetv2+std+1280                  0.014639                 0.016575
# resnet50v2+mean+2048                  0.201033                 0.224927
# resnet50v2+std+2048                   0.016264                 0.007717
# vgg16+mean+512                        0.206336                 0.270684
# vgg16+std+512                         0.014557                 0.018398
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.318753
# mobilenetv2+std+1280                  0.012573
# resnet50v2+mean+2048                  0.264442
# resnet50v2+std+2048                   0.011652
# vgg16+mean+512                        0.285734
# vgg16+std+512                         0.024547
# '10+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                   0.198576                    0.17539
# mobilenetv2+std+1280                     0.01759                   0.020418
# resnet50v2+mean+2048                    0.201587                   0.196791
# resnet50v2+std+2048                     0.022186                   0.026403
# vgg16+mean+512                          0.160768                   0.216636
# vgg16+std+512                           0.007237                   0.009471
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                   0.214212          0.393871
# mobilenetv2+std+1280                     0.00733          0.023162
# resnet50v2+mean+2048                    0.210609               NaN
# resnet50v2+std+2048                      0.02954               NaN
# vgg16+mean+512                          0.186081               NaN
# vgg16+std+512                           0.015362               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280               NaN               NaN  0.350255  0.454487
# mobilenetv2+std+1280                NaN               NaN  0.026475  0.037359
# resnet50v2+mean+2048                NaN               NaN  0.371591  0.434263
# resnet50v2+std+2048                 NaN               NaN  0.013582  0.024433
# vgg16+mean+512                      NaN          0.551396  0.384304  0.472677
# vgg16+std+512                       NaN          0.012293  0.020007  0.026686
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280  0.470153                   0.242069
# mobilenetv2+std+1280    0.04447                   0.012709
# resnet50v2+mean+2048   0.490346                   0.241768
# resnet50v2+std+2048    0.018197                   0.014399
# vgg16+mean+512         0.501367                   0.246054
# vgg16+std+512          0.016093                   0.009657
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                   0.259704                   0.270379
# mobilenetv2+std+1280                    0.016061                   0.018143
# resnet50v2+mean+2048                    0.242666                    0.25986
# resnet50v2+std+2048                     0.010336                   0.018082
# vgg16+mean+512                          0.277542                   0.285873
# vgg16+std+512                           0.012357                   0.011052
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.257428                 0.321981
# mobilenetv2+std+1280                  0.030607                 0.029453
# resnet50v2+mean+2048                   0.23148                   0.2762
# resnet50v2+std+2048                   0.025494                 0.030471
# vgg16+mean+512                        0.229901                 0.317007
# vgg16+std+512                         0.017047                 0.014894
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.360932
# mobilenetv2+std+1280                  0.020933
# resnet50v2+mean+2048                  0.278628
# resnet50v2+std+2048                   0.012614
# vgg16+mean+512                        0.344015
# vgg16+std+512                         0.014096
# '20+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                     0.2206                   0.194924
# mobilenetv2+std+1280                    0.037076                   0.017295
# resnet50v2+mean+2048                    0.229071                   0.246872
# resnet50v2+std+2048                      0.03241                   0.016953
# vgg16+mean+512                          0.228951                   0.258193
# vgg16+std+512                            0.02324                   0.040157
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                   0.212457          0.472047
# mobilenetv2+std+1280                    0.013542          0.020531
# resnet50v2+mean+2048                    0.240972               NaN
# resnet50v2+std+2048                     0.010463               NaN
# vgg16+mean+512                          0.303618               NaN
# vgg16+std+512                            0.03748               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280               NaN               NaN  0.431628   0.51674
# mobilenetv2+std+1280                NaN               NaN  0.026674  0.020989
# resnet50v2+mean+2048                NaN               NaN  0.436713  0.505986
# resnet50v2+std+2048                 NaN               NaN  0.017847  0.016223
# vgg16+mean+512                      NaN          0.627909  0.463833  0.546857
# vgg16+std+512                       NaN          0.029674  0.014186  0.024505
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280  0.542845                   0.297677
# mobilenetv2+std+1280   0.020827                   0.024505
# resnet50v2+mean+2048    0.55904                   0.299696
# resnet50v2+std+2048    0.011172                   0.007339
# vgg16+mean+512         0.585794                   0.300669
# vgg16+std+512          0.041284                   0.023362
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                   0.328384                   0.347919
# mobilenetv2+std+1280                    0.017335                   0.012403
# resnet50v2+mean+2048                    0.300744                   0.337906
# resnet50v2+std+2048                     0.010542                    0.01135
# vgg16+mean+512                          0.350078                   0.363681
# vgg16+std+512                           0.015514                   0.011786
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.342935                 0.426445
# mobilenetv2+std+1280                  0.025264                 0.028618
# resnet50v2+mean+2048                   0.27808                 0.302728
# resnet50v2+std+2048                   0.012009                 0.034473
# vgg16+mean+512                        0.262151                 0.393549
# vgg16+std+512                         0.034385                 0.045575
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.430258
# mobilenetv2+std+1280                  0.021295
# resnet50v2+mean+2048                  0.343827
# resnet50v2+std+2048                   0.027288
# vgg16+mean+512                        0.392511
# vgg16+std+512                         0.019514
# '5+GRAYSCALE'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                   0.138803                   0.182553
# mobilenetv2+std+1280                    0.022717                   0.013381
# resnet50v2+mean+2048                    0.178174                   0.149637
# resnet50v2+std+2048                     0.019331                    0.02389
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                          0.139277                    0.17536
# vgg16+std+512                           0.010475                   0.004662
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                   0.155628          0.369989
# mobilenetv2+std+1280                    0.007009          0.020351
# resnet50v2+mean+2048                    0.193299          0.354904
# resnet50v2+std+2048                     0.015304          0.008729
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                          0.203084               NaN
# vgg16+std+512                           0.026116               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# lbp+mean+59                         NaN               NaN       NaN       NaN
# lbp+std+59                          NaN               NaN       NaN       NaN
# mobilenetv2+mean+1280               NaN               NaN  0.308351  0.380319
# mobilenetv2+std+1280                NaN               NaN    0.0253  0.020021
# resnet50v2+mean+2048                NaN               NaN  0.304583  0.394559
# resnet50v2+std+2048                 NaN               NaN  0.008671  0.011953
# surf64+mean+257                     NaN               NaN       NaN       NaN
# surf64+std+257                      NaN               NaN       NaN       NaN
# vgg16+mean+512                      NaN          0.481002  0.306547  0.404305
# vgg16+std+512                       NaN          0.023803   0.01302  0.021893
#
#                         SVC+512 RandomForestClassifier+256  \
# lbp+mean+59                 NaN                        NaN
# lbp+std+59                  NaN                        NaN
# mobilenetv2+mean+1280   0.40993                   0.195686
# mobilenetv2+std+1280   0.026107                   0.008986
# resnet50v2+mean+2048   0.456092                   0.208402
# resnet50v2+std+2048    0.017809                   0.011118
# surf64+mean+257             NaN                        NaN
# surf64+std+257              NaN                        NaN
# vgg16+mean+512         0.437772                   0.208829
# vgg16+std+512          0.024306                   0.009349
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                   0.220987                   0.226665
# mobilenetv2+std+1280                    0.014034                   0.012597
# resnet50v2+mean+2048                    0.212569                    0.23441
# resnet50v2+std+2048                     0.021219                   0.017527
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                           0.23696                   0.250715
# vgg16+std+512                           0.009761                   0.008703
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                 0.236148                   0.2721
# mobilenetv2+std+1280                  0.012945                 0.014752
# resnet50v2+mean+2048                  0.192126                 0.219716
# resnet50v2+std+2048                   0.014201                 0.009727
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                        0.198228                 0.277803
# vgg16+std+512                         0.008953                 0.014628
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                 0.305312
# mobilenetv2+std+1280                   0.02369
# resnet50v2+mean+2048                  0.283032
# resnet50v2+std+2048                   0.030716
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                        0.310537
# vgg16+std+512                         0.013583
# '10+GRAYSCALE'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                   0.144788                   0.192222
# mobilenetv2+std+1280                    0.020402                   0.015609
# resnet50v2+mean+2048                     0.16625                   0.197091
# resnet50v2+std+2048                     0.023068                   0.025283
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                          0.159943                   0.245516
# vgg16+std+512                           0.023437                   0.014162
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                   0.205231          0.412954
# mobilenetv2+std+1280                    0.007814          0.039677
# resnet50v2+mean+2048                    0.199905               NaN
# resnet50v2+std+2048                     0.034239               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                           0.18824               NaN
# vgg16+std+512                           0.010957               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# lbp+mean+59                         NaN               NaN       NaN       NaN
# lbp+std+59                          NaN               NaN       NaN       NaN
# mobilenetv2+mean+1280               NaN               NaN  0.357998  0.441204
# mobilenetv2+std+1280                NaN               NaN   0.02295  0.013683
# resnet50v2+mean+2048                NaN               NaN   0.33542  0.436981
# resnet50v2+std+2048                 NaN               NaN  0.012016  0.030061
# surf64+mean+257                     NaN               NaN       NaN       NaN
# surf64+std+257                      NaN               NaN       NaN       NaN
# vgg16+mean+512                      NaN          0.549351  0.372547   0.47281
# vgg16+std+512                       NaN          0.042897  0.022289  0.027035
#
#                         SVC+512 RandomForestClassifier+256  \
# lbp+mean+59                 NaN                        NaN
# lbp+std+59                  NaN                        NaN
# mobilenetv2+mean+1280  0.446359                   0.238023
# mobilenetv2+std+1280   0.030539                   0.015439
# resnet50v2+mean+2048   0.485303                   0.235472
# resnet50v2+std+2048    0.031237                   0.011584
# surf64+mean+257             NaN                        NaN
# surf64+std+257              NaN                        NaN
# vgg16+mean+512         0.500835                   0.231742
# vgg16+std+512           0.03162                   0.013191
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                   0.255648                   0.263818
# mobilenetv2+std+1280                    0.007566                   0.015095
# resnet50v2+mean+2048                    0.245328                    0.27484
# resnet50v2+std+2048                     0.011734                   0.008315
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                          0.275894                   0.286566
# vgg16+std+512                            0.01419                   0.010958
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                  0.26175                 0.310845
# mobilenetv2+std+1280                  0.007211                 0.011293
# resnet50v2+mean+2048                  0.217762                 0.254477
# resnet50v2+std+2048                   0.011206                 0.020763
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                        0.231807                 0.324238
# vgg16+std+512                         0.015863                 0.015509
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                 0.341121
# mobilenetv2+std+1280                  0.020145
# resnet50v2+mean+2048                  0.319845
# resnet50v2+std+2048                   0.006882
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                        0.348554
# vgg16+std+512                          0.02465
# '20+GRAYSCALE'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                   0.219082                   0.254622
# mobilenetv2+std+1280                    0.022829                   0.015171
# resnet50v2+mean+2048                    0.231545                   0.249393
# resnet50v2+std+2048                     0.023696                   0.004264
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                          0.203859                   0.254757
# vgg16+std+512                           0.023706                   0.023286
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                   0.272844          0.463296
# mobilenetv2+std+1280                    0.008945          0.019299
# resnet50v2+mean+2048                    0.265569               NaN
# resnet50v2+std+2048                     0.024585               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                          0.235372               NaN
# vgg16+std+512                           0.014927               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# lbp+mean+59                         NaN               NaN       NaN       NaN
# lbp+std+59                          NaN               NaN       NaN       NaN
# mobilenetv2+mean+1280               NaN               NaN  0.426383  0.492926
# mobilenetv2+std+1280                NaN               NaN  0.026982  0.017485
# resnet50v2+mean+2048                NaN               NaN  0.413215  0.510242
# resnet50v2+std+2048                 NaN               NaN  0.021495  0.015276
# surf64+mean+257                     NaN               NaN       NaN       NaN
# surf64+std+257                      NaN               NaN       NaN       NaN
# vgg16+mean+512                      NaN          0.632575  0.440585  0.537879
# vgg16+std+512                       NaN          0.017032   0.02025  0.020126
#
#                         SVC+512 RandomForestClassifier+256  \
# lbp+mean+59                 NaN                        NaN
# lbp+std+59                  NaN                        NaN
# mobilenetv2+mean+1280  0.523651                   0.295437
# mobilenetv2+std+1280   0.032079                    0.02081
# resnet50v2+mean+2048   0.555597                   0.301934
# resnet50v2+std+2048    0.024953                   0.010485
# surf64+mean+257             NaN                        NaN
# surf64+std+257              NaN                        NaN
# vgg16+mean+512         0.571165                   0.305291
# vgg16+std+512          0.017968                    0.01959
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                    0.32172                   0.334128
# mobilenetv2+std+1280                     0.01457                     0.0117
# resnet50v2+mean+2048                    0.308737                    0.33327
# resnet50v2+std+2048                     0.011323                   0.019564
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                          0.342944                   0.353852
# vgg16+std+512                           0.015194                   0.029887
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                 0.327524                 0.383348
# mobilenetv2+std+1280                  0.027309                 0.033332
# resnet50v2+mean+2048                  0.269686                 0.310414
# resnet50v2+std+2048                   0.024043                 0.030713
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                        0.286575                 0.374023
# vgg16+std+512                         0.019307                 0.036889
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                 0.419861
# mobilenetv2+std+1280                  0.028978
# resnet50v2+mean+2048                  0.365086
# resnet50v2+std+2048                   0.022884
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                        0.421166
# vgg16+std+512                         0.015709
