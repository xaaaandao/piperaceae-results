# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from utils import create_sheets, get_dfs

dataset_name = 'br'
os.makedirs(dataset_name, exist_ok=True)
dfs = get_dfs()
path = '/media/xandao/d3b6c029-9e4c-4225-a0df-da4f12bf464c/br'
create_sheets(dfs, path)

# %%
for k, v in dfs.items():
    v.sort_index(inplace=True)
    display(k, v)
    v.to_csv(os.path.join(dataset_name, '%s.csv') % k, sep=';', float_format=',', quoting=2, na_rep=0)
# Out:
# '5+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                   0.003792                   0.003672
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                    0.005075                   0.005896
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                          0.003422                   0.007377
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                   0.002875          0.007524
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                    0.003857          0.005423
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                          0.005006          0.005095
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280          0.002956          0.008009   0.00602  0.002908
# mobilenetv2+std+1280                NaN               NaN       NaN       NaN
# resnet50v2+mean+2048           0.006819          0.011577  0.009572  0.008717
# resnet50v2+std+2048                 NaN               NaN       NaN       NaN
# vgg16+mean+512                 0.007422           0.00516  0.004302  0.003979
# vgg16+std+512                       NaN               NaN       NaN       NaN
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280   0.00508                        NaN
# mobilenetv2+std+1280        NaN                        NaN
# resnet50v2+mean+2048   0.009421                        NaN
# resnet50v2+std+2048         NaN                        NaN
# vgg16+mean+512         0.005792                    0.00308
# vgg16+std+512               NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                          0.003871                   0.003402
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.003518                 0.004726
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                  0.003413                 0.004375
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                        0.004233                 0.006086
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.001494
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                  0.005831
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                        0.011855
# vgg16+std+512                              NaN
# '10+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                   0.003108                   0.004642
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                    0.003534                   0.005456
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                          0.003705                   0.001762
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                   0.004788          0.011757
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                    0.007494          0.009552
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                          0.005122          0.010539
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280           0.00479          0.004375  0.008665  0.003888
# mobilenetv2+std+1280                NaN               NaN       NaN       NaN
# resnet50v2+mean+2048           0.005417          0.008046  0.008489  0.006836
# resnet50v2+std+2048                 NaN               NaN       NaN       NaN
# vgg16+mean+512                 0.009965           0.00903  0.006007  0.010572
# vgg16+std+512                       NaN               NaN       NaN       NaN
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280  0.005314                   0.003238
# mobilenetv2+std+1280        NaN                        NaN
# resnet50v2+mean+2048    0.00746                        NaN
# resnet50v2+std+2048         NaN                        NaN
# vgg16+mean+512          0.00902                   0.002854
# vgg16+std+512               NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                   0.005109                   0.007397
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                           0.00731                   0.006662
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.005117                 0.005199
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                  0.006736                 0.007181
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                        0.003757                  0.00926
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.005264
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                   0.00639
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                        0.011914
# vgg16+std+512                              NaN
# '20+RGB'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# mobilenetv2+mean+1280                   0.006035                   0.009812
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                    0.008958                   0.004688
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                          0.004989                   0.010258
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# mobilenetv2+mean+1280                   0.005898          0.008569
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                    0.005875           0.00819
# resnet50v2+std+2048                          NaN               NaN
# vgg16+mean+512                          0.005987          0.006451
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512   SVC+256   SVC+400  \
# mobilenetv2+mean+1280           0.00943           0.01457  0.006455   0.01184
# mobilenetv2+std+1280                NaN               NaN       NaN       NaN
# resnet50v2+mean+2048           0.013061           0.01136  0.007915  0.012336
# resnet50v2+std+2048                 NaN               NaN       NaN       NaN
# vgg16+mean+512                 0.008861          0.004367  0.006721   0.01454
# vgg16+std+512                       NaN               NaN       NaN       NaN
#
#                         SVC+512 RandomForestClassifier+256  \
# mobilenetv2+mean+1280  0.009625                   0.002947
# mobilenetv2+std+1280        NaN                        NaN
# resnet50v2+mean+2048   0.012304                   0.007232
# resnet50v2+std+2048         NaN                        NaN
# vgg16+mean+512         0.011066                   0.003486
# vgg16+std+512               NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# mobilenetv2+mean+1280                   0.004717                   0.002855
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                    0.004839                   0.003683
# resnet50v2+std+2048                          NaN                        NaN
# vgg16+mean+512                          0.004091                   0.001796
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# mobilenetv2+mean+1280                 0.006993                 0.005378
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                  0.005866                  0.01039
# resnet50v2+std+2048                        NaN                      NaN
# vgg16+mean+512                        0.004558                 0.003613
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# mobilenetv2+mean+1280                 0.009937
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                  0.009223
# resnet50v2+std+2048                        NaN
# vgg16+mean+512                        0.006234
# vgg16+std+512                              NaN
# '5+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '10+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
# '20+grayscale'
#                       DecisionTreeClassifier+256 DecisionTreeClassifier+400  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       DecisionTreeClassifier+512 MLPClassifier+256  \
# lbp+mean+59                                  NaN               NaN
# lbp+std+59                                   NaN               NaN
# mobilenetv2+mean+1280                        NaN               NaN
# mobilenetv2+std+1280                         NaN               NaN
# resnet50v2+mean+2048                         NaN               NaN
# resnet50v2+std+2048                          NaN               NaN
# surf64+mean+257                              NaN               NaN
# surf64+std+257                               NaN               NaN
# vgg16+mean+512                               NaN               NaN
# vgg16+std+512                                NaN               NaN
#
#                       MLPClassifier+400 MLPClassifier+512 SVC+256 SVC+400  \
# lbp+mean+59                         NaN               NaN     NaN     NaN
# lbp+std+59                          NaN               NaN     NaN     NaN
# mobilenetv2+mean+1280               NaN               NaN     NaN     NaN
# mobilenetv2+std+1280                NaN               NaN     NaN     NaN
# resnet50v2+mean+2048                NaN               NaN     NaN     NaN
# resnet50v2+std+2048                 NaN               NaN     NaN     NaN
# surf64+mean+257                     NaN               NaN     NaN     NaN
# surf64+std+257                      NaN               NaN     NaN     NaN
# vgg16+mean+512                      NaN               NaN     NaN     NaN
# vgg16+std+512                       NaN               NaN     NaN     NaN
#
#                       SVC+512 RandomForestClassifier+256  \
# lbp+mean+59               NaN                        NaN
# lbp+std+59                NaN                        NaN
# mobilenetv2+mean+1280     NaN                        NaN
# mobilenetv2+std+1280      NaN                        NaN
# resnet50v2+mean+2048      NaN                        NaN
# resnet50v2+std+2048       NaN                        NaN
# surf64+mean+257           NaN                        NaN
# surf64+std+257            NaN                        NaN
# vgg16+mean+512            NaN                        NaN
# vgg16+std+512             NaN                        NaN
#
#                       RandomForestClassifier+400 RandomForestClassifier+512  \
# lbp+mean+59                                  NaN                        NaN
# lbp+std+59                                   NaN                        NaN
# mobilenetv2+mean+1280                        NaN                        NaN
# mobilenetv2+std+1280                         NaN                        NaN
# resnet50v2+mean+2048                         NaN                        NaN
# resnet50v2+std+2048                          NaN                        NaN
# surf64+mean+257                              NaN                        NaN
# surf64+std+257                               NaN                        NaN
# vgg16+mean+512                               NaN                        NaN
# vgg16+std+512                                NaN                        NaN
#
#                       KNeighborsClassifier+256 KNeighborsClassifier+400  \
# lbp+mean+59                                NaN                      NaN
# lbp+std+59                                 NaN                      NaN
# mobilenetv2+mean+1280                      NaN                      NaN
# mobilenetv2+std+1280                       NaN                      NaN
# resnet50v2+mean+2048                       NaN                      NaN
# resnet50v2+std+2048                        NaN                      NaN
# surf64+mean+257                            NaN                      NaN
# surf64+std+257                             NaN                      NaN
# vgg16+mean+512                             NaN                      NaN
# vgg16+std+512                              NaN                      NaN
#
#                       KNeighborsClassifier+512
# lbp+mean+59                                NaN
# lbp+std+59                                 NaN
# mobilenetv2+mean+1280                      NaN
# mobilenetv2+std+1280                       NaN
# resnet50v2+mean+2048                       NaN
# resnet50v2+std+2048                        NaN
# surf64+mean+257                            NaN
# surf64+std+257                             NaN
# vgg16+mean+512                             NaN
# vgg16+std+512                              NaN
